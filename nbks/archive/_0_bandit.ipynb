# %% [markdown]
# # Multiarm bandit

# %% [markdown]
# - 1 bandit with N arms (typically N=10 in their examples)
# - Each arm has a true mean reward (action value) drawn from a normal distribution
# - Pulling an arm gives a reward sampled from a normal distribution around that arm's true mean
# - The goal is to maximize cumulative reward over time
#
# ![image.png](attachment:image.png)
